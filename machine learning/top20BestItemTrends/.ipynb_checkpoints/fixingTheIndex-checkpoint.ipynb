# %%
import pandas as pd
import numpy as np

# %%
#I figured out an easier way on excel, therefore i am saving this cell for future
# references in terms of finding business days of a give ndate range.
#=======================================================================
#=======================================================================
#=======================================================================
# # Creating a date range from Jan 2 to Nov 4
# # data['date']= pd.date_range(start = '1/2/2019', end = '11/4/2019')

# len(data)

# len(pd.bdate_range(start = '1/2/2019', end = '11/4/2019'))

# # Trying to match the 219 with 215, so i will have to find the dates that do not match
# date = pd.bdate_range(start = '1/2/2019', end = '11/4/2019')
# dateDf= pd.DataFrame(date)
# dateDf.head()
# data
#=======================================================================
#=======================================================================
#=======================================================================

# %%
len(data.columns)# len(data)
# Out:
# 120

# %%
bestSellingItems = ["3MD-712-036",
"DEN-80395",
"3MD-3525(TE)",
"SUL-21115",
"KER-31513(EU)",
"3MD-3525(E)",
"DEN-610007",
"KER-33872",
"KRO-KRM302",
"3MD-56877",
"KER-36052(EU)",
"3MD-31642(E)",
"KOD-1753664(E)",
"SIR-6176528",
"KUL-65872354",
"DEN-666220",
"KER-33351",
"3MD-6020A2(E)",
"3MD-712-035",
"SIR-6176510"]

# %%
data = pd.read_csv("top20BestSellingItems.csv")
data = data.fillna(0)
data = data.set_index('Date')

# %%
j = 0
for i in range(6,240,12):
#     if i == 6 :
#         data.insert(i,f"ROS < Q1Start: {bestSellingItems[j]}",'') #Q1Start = .2955
# #     else:
    data.insert(i-j,f"ROS < Q1Start: {bestSellingItems[j]}",'') #Q1Start = .2955
    data.insert(i+1-j,f"1: Q1 <= ROS < Q2Start, 0: else: {bestSellingItems[j]}",'') # Q2Start = .3626
    data.insert(i+2-j,f"1: Q2 <= ROS < Q3Start, 0: else: {bestSellingItems[j]}",'') # Q3Start = .4223
    data.insert(i+3-j,f"1: Q3 <= ROS < Q4Start, 0: else: {bestSellingItems[j]}",'') # Q4Start = .4625
    data.insert(i+4-j,f"1: Q4End < ROS, 0: else: {bestSellingItems[j]}",'') # Q4End = .5987    
    j = j + 1
    print(len(data.columns))
# Out:
# 125
# 130
# 135
# 140
# 145
# 150
# 155
# 160
# 165
# 170
# 175
# 180
# 185
# 190
# 195
# 200
# 205
# 210
# 215
# 220

# %%
# j = 0
# for i in range(6,len(data.columns),6):
#     print(j)
#     j = j + 1
for i in data.columns:
    print(i)
# Out:
# 3MD-712-036_Profit
# 3MD-712-036_Avg. return on sales
# 3MD-712-036_Distinct count of order id
# 3MD-712-036_quantity
# 3MD-712-036_profitPerQuantitySold
# 3MD-712-036_profitPerOrderMade
# ROS < Q1Start: 3MD-712-036
# 1: Q1 <= ROS < Q2Start, 0: else: 3MD-712-036
# 1: Q2 <= ROS < Q3Start, 0: else: 3MD-712-036
# 1: Q3 <= ROS < Q4Start, 0: else: 3MD-712-036
# 1: Q4End < ROS, 0: else: 3MD-712-036
# DEN-80395_Profit
# DEN-80395_Avg. return on sales
# DEN-80395_Distinct count of order id
# DEN-80395_quantity
# DEN-80395_profitPerQuantitySold
# DEN-80395_profitPerOrderMade
# ROS < Q1Start: DEN-80395
# 1: Q1 <= ROS < Q2Start, 0: else: DEN-80395
# 1: Q2 <= ROS < Q3Start, 0: else: DEN-80395
# 1: Q3 <= ROS < Q4Start, 0: else: DEN-80395
# 1: Q4End < ROS, 0: else: DEN-80395
# 3MD-3525(TE)_Profit
# 3MD-3525(TE)_Avg. return on sales
# 3MD-3525(TE)_Distinct count of order id
# 3MD-3525(TE)_quantity
# 3MD-3525(TE)_profitPerQuantitySold
# 3MD-3525(TE)_profitPerOrderMade
# ROS < Q1Start: 3MD-3525(TE)
# ...

# %%
for i in range(0,len(data['3MD-712-036_Profit'])):
    if data.iloc[[i],[1]] < 0.2955:
        for j in range(6,len(data.columns),6):
            data.iloc[[i],[6]] = 1
            data.iloc[[i],[6+1]] = 0
            data.iloc[[i],[6+2]] = 0
            data.iloc[[i],[6+3]] = 0
            data.iloc[[i],[6+4]] = 0
    if data.iloc[[i],[1]] < 0.2955:
        for j in range(6,len(data.columns),6):
            data.iloc[[i],[6]] = 1
            data.iloc[[i],[6+1]] = 0
            data.iloc[[i],[6+2]] = 0
            data.iloc[[i],[6+3]] = 0
            data.iloc[[i],[6+4]] = 0

# %%
f"ROS < Q1Start: {bestSellingItems[j]}" #Q1Start = .2955
f"1: Q1 <= ROS < Q2Start, 0: else: {bestSellingItems[j]}" # Q2Start = .3626
f"1: Q2 <= ROS < Q3Start, 0: else: {bestSellingItems[j]}" # Q3Start = .4223
f"1: Q3 <= ROS < Q4Start, 0: else: {bestSellingItems[j]}" # Q4Start = .4625
f"1: Q4End < ROS, 0: else: {bestSellingItems[j]}" # Q4End = .5987

# %%
if .10 <= data.iloc[[1],[1]] <= 0.2955:
    print("yes")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-7d1ca720d95e> in <module>
# ----> 1 if .10 <= data.iloc[[1],[1]] <= 0.2955:
#       2     print("yes")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
t = data.iloc[[1],[1]][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-4950c0efa817> in <module>
# ----> 1 t = data.iloc[[1],[1]][0]
#
# ...

# %%
# Out:
#                 3MD-712-036_Avg. return on sales
# Date
# 2019-January-3                               0.0

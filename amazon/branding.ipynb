# %%
import pandas as pd

# %%
branding = pd.read_csv("../BRANDINGGoodCopy of ROI Combined - 11-04-2019 (version 1).csv")

# %%
for i in range(0,len(branding['SKU'])):
    branding['SKU'][i] = branding['SKU'][i].upper()

# %%
branding
# Out:
#          Brand             SKU  \
# 0      3M ESPE  3MD-10771(E) 2
# 1      3M ESPE      3MD-10771J
# 2      3M ESPE    3MD-12627(E)
# 3      3M ESPE      3MD-1942FB
# 4      3M ESPE      3MD-1942FR
# 5      3M ESPE        3MD-1954
# 6      3M ESPE       3MD-1954N
# 7      3M ESPE        3MD-1956
# 8      3M ESPE       3MD-1981C
# 9      3M ESPE       3MD-1981F
# 10     3M ESPE       3MD-1981M
# 11     3M ESPE      3MD-1981SF
# 12     3M ESPE       3MD-1982C
# 13     3M ESPE       3MD-1982F
# 14     3M ESPE       3MD-1982M
# 15     3M ESPE      3MD-1982SF
# 16     3M ESPE      3MD-1983RA
# 17     3M ESPE       3MD-2000F
# 18     3M ESPE        3MD-2380
# 19     3M ESPE       3MD-2381C
# 20     3M ESPE       3MD-2381F
# 21     3M ESPE       3MD-2381M
# 22     3M ESPE      3MD-2381SF
# 23     3M ESPE       3MD-2382C
# 24     3M ESPE       3MD-2382F
# 25     3M ESPE       3MD-2382M
# 26     3M ESPE      3MD-2382SF
# 27     3M ESPE    3MD-30103(E)
# 28     3M ESPE    3MD-30413(E)
# ...

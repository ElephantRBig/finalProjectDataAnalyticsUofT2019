# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"inventoryNov11.csv",encoding = "ISO-8859-1")

# %%
dataset.groupby([])
# Out:
#        snapshot-date                       sku  \
# 0         2019-01-01                SOT-160214
# 1         2019-01-01               LUX-NEO120B
# 2         2019-01-01                MOL-295300
# 3         2019-01-01                CON-187660
# 4         2019-01-01                SOT-140172
# 5         2019-01-01               LUX-NEO185W
# 6         2019-01-01                   3M-1539
# 7         2019-01-01               WEL-52432-U
# 8         2019-01-01                 3MM-1626W
# 9         2019-01-01                MOL-1443-1
# 10        2019-01-01               3M-1527-1-6
# 11        2019-01-01              MOL-281200-1
# 12        2019-01-01                CON-187660
# 13        2019-01-01                MOL-295300
# 14        2019-01-01               WEL-52432-U
# 15        2019-01-01                MOL-281000
# 16        2019-01-01                 3MM-1626W
# 17        2019-01-01  3MM-1626W(Double Pack-2)
# 18        2019-01-01                   3M-1539
# ...

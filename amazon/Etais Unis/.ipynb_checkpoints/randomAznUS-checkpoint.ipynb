# %%
import pandas as pd

# %%
t = pd.read_csv(r"orders1.csv")

# %%
t
# Out:
#              date             time             order id          group-sku  \
# 0      01-01-2019   5:47:14 AM PST  113-6367239-5079454      3MM-1626W(10)
# 1      01-01-2019   5:17:36 PM PST  111-9068523-7753045       3MM-2862(X2)
# 2      01-01-2019   6:25:46 PM PST  113-0264648-2380248       3MM-2862(X3)
# 3      01-01-2019   6:53:45 PM PST  113-9437923-0745861          3MM-2113R
# 4      01-01-2019   7:28:49 PM PST  111-9301430-4157819         3MM-1527-2
# 5      01-01-2019   8:13:43 PM PST  112-6256754-8717046         3MM-1527-2
# 6      01-01-2019   8:18:38 PM PST  114-9064258-3475457      3MM-1626W(25)
# 7      01-01-2019   8:24:24 PM PST  113-4195757-5332227           MOL-1443
# 8      01-01-2019   8:39:47 PM PST  114-8940069-7155464       3MM-1539(X3)
# 9      01-01-2019   8:46:40 PM PST  114-3972055-6192239       3MM-2862(X3)
# 10     01-01-2019   8:52:37 PM PST  114-5415143-7986625           MOL-1451
# ...

# %%
print(f"the total amount of orders is  : {len(t['order id'])}")
print(f"The total amount of quantity sold is : {t['quantity'].sum()}")
# Out:
# the total amount of orders is  : 33789
# The total amount of quantity sold is : 40317

# %%
t.groupby('date').agg({'order id':'count','quantity':'sum'})
# Out:
#             order id  quantity
# date
# 01-01-2019        34        41
# 01-02-2019        66       117
# 01-03-2019       111       127
# 01-04-2019        49        54
# 01-05-2019       184       221
# 01-06-2019       106       107
# 01-07-2019       462       548
# 01-08-2019        86       111
# 01-09-2019        16        17
# 01-10-2019        45        60
# 01-11-2019        13        22
# 02-01-2019       201       261
# 02-02-2019        92       143
# 02-03-2019        84       117
# 02-04-2019        34        35
# 02-05-2019       174       208
# 02-06-2019       120       129
# 02-07-2019       423       505
# 02-08-2019        92       103
# 02-09-2019        18        21
# 02-10-2019        50        60
# 02-11-2019         5         6
# 03-01-2019       168       225
# 03-02-2019        75       118
# 03-03-2019        81       106
# 03-04-2019        47        58
# 03-05-2019       156       195
# 03-06-2019       154       159
# 03-07-2019       406       478
# ...

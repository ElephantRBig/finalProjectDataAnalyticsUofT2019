# %%
import pandas as pd

# %%
t = pd.read_csv(r'y_totalCost.csv')

# %%
t = t.set_index('sku')
list = [
"TOR-MS407W(B)",
"MDL-NON80328",
"3MM-R1547(10)",
"3MM-6166",
"3MM-6165",
"3MM-6152",
"3MM-1624W(B)",
"3MM-2560(X2)",
"CON-22771"
]

# %%
# t = t.set_index('sku')
t
for i in list:
     t = t.drop(i)

t= t.reset_index()

t
# Out:
#                           sku  Total-Quantity-Sold  Total-Cost  \
# 0               3MM-1527-1-12                  297     2834.78
# 1                  3MM-1527-2                  493     5452.57
# 2                    3MM-1537                   36      524.61
# 3                3MM-1537(X4)                   90     1274.76
# 4                    3MM-1539                  147     2103.29
# 5                3MM-1539(20)                  109     1908.66
# 6                3MM-1539(X3)                  269     3696.76
# 7                3MM-1539(X4)                   45      782.10
# 8                 3MM-1547(B)                   12      239.26
# 9                   3MM-1622W                   40      790.19
# 10                  3MM-1624W                  202     2883.01
# 11              3MM-1624W(20)                  183      699.76
# 12             3MM-1624W(20B)                  921     3964.73
# 13                  3MM-1626W                  376     5996.07
# ...

# %%
t.to_csv(r'y_totalCostNoOutliers.csv')

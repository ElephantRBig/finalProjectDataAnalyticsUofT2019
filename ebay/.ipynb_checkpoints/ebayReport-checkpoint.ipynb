# %%
import pandas as pd

# %%
ebayReport = pd.read_csv('cleanedEbaySalesData.csv', encoding = 'ISO-8859-1')

# %%
ebayReport.head()
# Out:
#           Type        Date    Num                          Ship To Address 1  \
# 0      Invoice  02/04/2019  14496                           Dallin Young DDS
# 1      Invoice  02/04/2019  14496                           Dallin Young DDS
# 2  Credit Memo  02/04/2019  14500                           Dallin Young DDS
# 3  Credit Memo  02/04/2019  14500                           Dallin Young DDS
# 4      Invoice  04/12/2019  17163  Glennallen Family Dentistry Dr. Kevin She
#
#                    Ship To Address 2 Ship Postal Code             Item  Qty  \
# 0                 114 Minnie Street,            99701     3MD-51102(E)    4
# 1                 114 Minnie Street,            99701  Shipping Charge    1
# 2                 114 Minnie Street,            99701     3MD-51102(E)   -4
# 3                 114 Minnie Street,            99701  Shipping Charge   -1
# 4  Mile 187 Glenn highway/mabel lane            99588     DEN-66002861    1
#
#    Sales Price  Amount
# 0        30.00  120.00
# 1         4.00    4.00
# 2        30.00 -120.00
# 3         4.00   -4.00
# 4        59.99   59.99

# %%
# Dropping an unnecessary column 
ebayReport = ebayReport.drop(columns = {'Sales Price'})

# Renaming a column to properly represent it's content
ebayReport = ebayReport.rename(columns = {'Amount':'Sales Total'})

# Dropping an unnecessary column 
ebayReport = ebayReport.drop(columns = {'Ship To Address 1'})

# Renaming a column to properly represent it's content
ebayReport = ebayReport.rename(columns = {'Ship To Address 2':'Address'})

# Renaming a column to properly represent it's content
ebayReport = ebayReport.rename(columns ={'Num':'Invoice Number'})

# %%
ebayReport = ebayReport.loc[ebayReport['Type']=='Invoice']

# %%
# from dfply import * 
# data= pd.read_csv('cleanedEbaySalesData.csv', encoding = 'ISO-8859-1')

# data >> select(X.Type, X.Date, X.Qty) >> mask(X.Type == "Invoice") >> head(3) 

# data >> group_by(X.Type) >> summarize(TotalQuantity = X.Qty.sum()) 

# data >> arrange(X.Date, ascending = False) >> head(5)

# %%
ebayReport.head()
# Out:
#       Type        Date  Invoice Number                            Address  \
# 0  Invoice  02/04/2019           14496                 114 Minnie Street,
# 1  Invoice  02/04/2019           14496                 114 Minnie Street,
# 4  Invoice  04/12/2019           17163  Mile 187 Glenn highway/mabel lane
# 5  Invoice  04/12/2019           17163  Mile 187 Glenn highway/mabel lane
# 8  Invoice  01/28/2019           14050                  412 E Pioneer Ave
#
#   Ship Postal Code             Item  Qty  Sales Total
# 0            99701     3MD-51102(E)    4       120.00
# 1            99701  Shipping Charge    1         4.00
# 4            99588     DEN-66002861    1        59.99
# 5            99588  Shipping Charge    1         4.00
# 8            99603       3MD-6021A3    3       170.85

# %%
# In this cell, i wil be adding the main IDs first and then landing costs to each item by importing the 'databaseVersion1' 
databaseLandingCosts = pd.read_csv('net32CostOfGoods.csv')

# %%
databaseLandingCosts.head()
# Out:
#            Item                                        Description    Cost
# 0  3MD-10771(E)  3M ESPE IMPRINT 3 HEAVY BODY REFILL CARTRIDGES...   76.67
# 1    3MD-10771J  3M ESPE IMPRINT 3 HEAVY BODY CARTRIDGE JUMBO P...  298.09
# 2  3MD-12627(E)   3M ESPE CLINPRO SEALANT SYRINGE REFILL 10 X1.2ML   10.66
# 3    3MD-1942FB                 3M ESPE MASKS FLUID RESIST (50/BX)   18.11
# 4    3MD-1942FR                 3M ESPE MASKS FLUID RESIST (50/BX)   18.11

# %%
# Adding in the landing costs
ebayReport['landing cost'] = '0'

for i in range(0,len(ebayReport['Item'].unique())):
    for j in range(0,len(databaseLandingCosts['Item'].unique())):
        if ebayReport['Item'].unique()[i] == databaseLandingCosts['Item'][j]:
            ebayReport.loc[ebayReport['Item']==ebayReport['Item'].unique()[i],'landing cost'] = databaseLandingCosts['Cost'][j]

# %%
ebayReportNoSC = ebayReport.loc[ebayReport['Item'] != 'Shipping Charge']

# %%
ebayReportNoSC
# Out:
#           Type        Date  Invoice Number                            Address  \
# 0      Invoice  02/04/2019           14496                 114 Minnie Street,
# 4      Invoice  04/12/2019           17163  Mile 187 Glenn highway/mabel lane
# 8      Invoice  01/28/2019           14050                  412 E Pioneer Ave
# 10     Invoice  01/03/2019           12968                     605 Marine Ave
# 11     Invoice  01/03/2019           12968                     605 Marine Ave
# 12     Invoice  07/31/2019           21947        10767 KENAI SPUR HWY, STE A
# 14     Invoice  02/04/2019           14469             411 Rezanof Drive East
# 16     Invoice  03/08/2019           15637               203 S SANTA CLAUS LN
# 18     Invoice  05/09/2019           18261               203 S SANTA CLAUS LN
# 22     Invoice  07/18/2019           21370                   806 south nordic
# 26     Invoice  01/25/2019           14042                159 Riverside Drive
# 28     Invoice  02/21/2019           15194                  6 Franklin Street
# 29     Invoice  05/16/2019           18523                  6 Franklin Street
# 30     Invoice  02/14/2019           14953           1695 Golden Springs Road
# 32     Invoice  02/28/2019           15500           1695 Golden Springs Road
# 34     Invoice  04/10/2019           17078           1695 Golden Springs Road
# 36     Invoice  06/11/2019           19580           1695 Golden Springs Road
# 38     Invoice  01/25/2019           13996                      313 E 10th St
# 40     Invoice  06/25/2019           20247                      313 E 10th St
# 42     Invoice  01/15/2019           13460              200 East Hobbs Street
# 44     Invoice  01/03/2019           12988                  778 North Dean Rd
# 45     Invoice  01/30/2019           14228                  778 North Dean Rd
# 47     Invoice  04/03/2019           16742                  778 North Dean Rd
# 49     Invoice  05/21/2019           18677                  778 North Dean Rd
# 51     Invoice  07/09/2019           20799                  778 North Dean Rd
# 53     Invoice  07/31/2019           21916       778 North Dean Rd, Suite:500
# 55     Invoice  05/03/2019           17985                867 North Dean Road
# 57     Invoice  04/15/2019           17263           724 N. Dean Rd Suite 200
# 59     Invoice  07/03/2019           20569           724 N. Dean Rd Suite 200
# 61     Invoice  07/17/2019           21282                      836 N DEAN RD
# ...        ...         ...             ...                                ...
# 17095  Invoice  06/25/2019           20238                   6803 Sheridan Rd
# 17097  Invoice  07/12/2019           21065         4707 Washington Road Ste 4
# 17099  Invoice  04/23/2019           17579                  340 East Reed Ave
# 17101  Invoice  01/04/2019           12995                 1300 W LINCOLN AVE
# 17103  Invoice  03/18/2019           16112                 1300 W LINCOLN AVE
# 17104  Invoice  03/18/2019           16112                 1300 W LINCOLN AVE
# 17105  Invoice  03/18/2019           16112                     3113 S 13th St
# 17106  Invoice  04/01/2019           16619                     3113 S 13th St
# 17108  Invoice  05/07/2019           18140                     3113 S 13th St
# 17110  Invoice  04/05/2019           16882              2700 W Lincoln Avenue
# 17112  Invoice  05/24/2019           18933              2700 W Lincoln Avenue
# 17114  Invoice  07/30/2019           21857              2700 W Lincoln Avenue
# 17116  Invoice  01/14/2019           13385             5542 W FOND DU LAC AVE
# 17118  Invoice  04/16/2019           17324                   9758 W. Lake Ave
# 17120  Invoice  01/22/2019           13748              1320 S Green Bay Road
# 17122  Invoice  03/06/2019           15686              1320 S Green Bay Road
# 17124  Invoice  04/02/2019           16713              1320 S Green Bay Road
# 17125  Invoice  04/08/2019           16956              1320 S Green Bay Road
# 17127  Invoice  05/06/2019           18053              1320 S Green Bay Road
# 17128  Invoice  07/30/2019           21832                    4425 Taylor Ave
# 17129  Invoice  06/26/2019           20309                    4425 Taylor Ave
# 17130  Invoice  06/26/2019           20309                    4425 Taylor Ave
# 17131  Invoice  07/11/2019           20955                    4425 Taylor Ave
# 17133  Invoice  06/19/2019           19987                1515 S Green Bay Rd
# 17135  Invoice  05/07/2019           18144             126 West Wisconsin Ave
# 17137  Invoice  05/24/2019           18954             126 West Wisconsin Ave
# 17139  Invoice  02/21/2019           15223                   151 E FOREST AVE
# 17141  Invoice  06/20/2019           20033                   151 E FOREST AVE
# 17143  Invoice  05/09/2019           18282                   8852 S BROOK CIR
# 17144  Invoice  02/21/2019           15171                   8852 S BROOK CIR
#
#       Ship Postal Code                Item  Qty  Sales Total landing cost
# 0                99701        3MD-51102(E)    4       120.00        24.28
# 4                99588        DEN-66002861    1        59.99         41.1
# 8                99603          3MD-6021A3    3       170.85        40.25
# 10               99611          3MD-5905A3   10       420.00        27.98
# 11               99611          3MD-5905A2   10       420.00        27.98
# 12          99611-7836        3MD-51102(E)    3        98.97        24.28
# 14               99615      KOD-1163401(E)    4       184.80        36.57
# 16          99705-7704        3MD-31642(E)    2       387.98       154.79
# 18          99705-7704        3MD-31642(E)    1       188.98       154.79
# 22               99833          CWH-H09946    5       159.95        22.08
# 26               99685            LOK-559B    2        39.98        11.08
# 28               35010        3MD-30103(E)    1       243.00       187.65
# 29               35010        3MD-30103(E)    1       245.00       187.65
# 30               36207        3MD-30413(E)    1       181.99        104.9
# 32               36207          DEN-610007    4       147.20        22.48
# 34               36207         SSW-15095-5    2        51.00        17.08
# 36               36207         SSW-15095-5    2        51.00        17.08
# 38               36207          ULT-131(E)    6        61.50         6.06
# 40               36207             ULT-168    1        85.50        48.18
# 42               35611        3MD-31642(E)    1       191.00       154.79
# 44               36830        3MD-31731(E)    2       397.00            0
# 45               36830            3MD-1954    2        43.40        14.29
# 47               36830            3MD-1954    2        42.90        14.29
# 49               36830           KER-33351    1        32.20         18.5
# 51               36830            3MD-1954    2        46.50        14.29
# 53               36830           KER-33351    2        57.98         18.5
# 55               36830            3MD-7302    1        63.20        10.01
# 57               36830           3MD-56877    1        88.99        41.29
# 59               36830           DEN-80392    1       108.50         69.5
# 61          36830-9401        HUF-S204S9E2    4       123.60        17.05
# ...                ...                 ...  ...          ...          ...
# 17095            53215        HUF-S204S9E2    1        35.99        17.05
# 17097       53216-1200              FFX-JG    1        98.00            0
# 17099            54548         SDI-8100045    4       159.96        22.31
# 17101            53406           SSW-13330    1       135.00        88.56
# 17103            53406         PRE-9007072    5       123.00        16.55
# 17104            53406         PRE-9007131    5       124.75        16.27
# 17105            53406         BEA-FGOS557    1       185.00            0
# 17106            53406         3MD-3525(E)    1       122.99        75.24
# 17108            53406            SHO-0413    2        44.00         9.36
# 17110            53405          3MD-5905A2    2        79.98        27.98
# 17112            53405          3MD-5905A3    2        81.98        27.98
# 17114            53406           KER-33351    2        57.98         18.5
# 17116            54956           3MD-44130    5        49.50            0
# 17118            54956        DEN-61605002    1        71.50            0
# 17120       54956-2758  KAV-0.411.9680(EU)    4       116.80            0
# 17122       54956-2758            SHO-0241   10       155.00            0
# 17124            53574           KER-35129   10       279.50        20.83
# 17125       53154-3942      KAV-0.411.9911    3        21.30         2.52
# 17127              NaN         3MD-712-036    4       500.00        42.57
# 17128              NaN           KER-35129   10       286.50        20.83
# 17129              NaN            SHO-0413    6        89.94         9.36
# 17130              NaN          GCD-000239    3       203.70        57.64
# 17131              NaN           3MD-30600    2        43.70         13.5
# 17133              NaN            SHO-0500    1        69.99        27.86
# 17135              NaN        TOK-13312(E)    1        68.99            0
# 17137              NaN        TOK-13311(E)    1        73.99            0
# 17139              NaN            VOC-1864    1        74.90        48.83
# 17141              NaN            SHO-0413    2        34.20         9.36
# 17143              NaN            PAR-S370    1       240.00            0
# 17144              NaN          DEN-610007    1        39.38        22.48
#
# [10314 rows x 9 columns]

# %%
ebayReport['landing cost'].unique()
# Out:
# array(['0', 3.43], dtype=object)
